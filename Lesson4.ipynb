# %%
import pandas as pd
import numpy as np

# %%
filepath = r'C:\Users\serha\OneDrive\Desktop\Data_Science_New_Era\Data_Science_New_Era\dataset.csv'

df = pd.read_csv(filepath)
df = pd.read_csv(filepath, parse_dates=['Order Date', 'Ship Date'])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          10000 non-null  str
#  1   Country         10000 non-null  str
#  2   Item Type       10000 non-null  str
#  3   Sales Channel   10000 non-null  str
#  4   Order Priority  10000 non-null  str
#  5   Order Date      10000 non-null  datetime64[us]
#  6   Order ID        10000 non-null  int64
#  7   Ship Date       10000 non-null  datetime64[us]
#  8   Units Sold      10000 non-null  int64
#  9   Unit Price      10000 non-null  float64
#  10  Unit Cost       10000 non-null  float64
#  11  Total Revenue   10000 non-null  float64
#  12  Total Cost      10000 non-null  float64
#  13  Total Profit    10000 non-null  float64
# dtypes: datetime64[us](2), float64(5), int64(2), str(5)
# memory usage: 1.1 MB

# %%
df['Item Type']
# Out:
# 0       Office Supplies
# 1             Beverages
# 2            Vegetables
# 3             Household
# 4             Beverages
#              ...
# 9995          Beverages
# 9996          Cosmetics
# 9997         Vegetables
# 9998               Meat
# 9999             Snacks
# Name: Item Type, Length: 10000, dtype: str

# %%
# SELECT * FROm DF WHERE 'Item Type' in ('Beverages','Vegetables') And 'Unit Price'>100

df2 = df.loc[(df['Item Type'] =='Beverages') | (df['Item Type'] =='Vegetables') & (df['Unit Price'] > 10.0)]
df2 = df.loc[(df['Item Type'].isin(['Beverages','Vegetables'])) & (df['Unit Price']>50)]

df2
# Out:
#                                  Region                           Country  \
# 2          Middle East and North Africa                          Pakistan
# 6                                  Asia                              Laos
# 25                               Europe                     Liechtenstein
# 33                               Europe                        San Marino
# 53                   Sub-Saharan Africa                             Ghana
# ...                                 ...                               ...
# 9949  Central America and the Caribbean            Saint Kitts and Nevis
# 9980                               Asia                              Laos
# 9982       Middle East and North Africa                          Tunisia
# 9986                             Europe                            Greece
# 9997                 Sub-Saharan Africa  Democratic Republic of the Congo
#
#        Item Type Sales Channel Order Priority Order Date   Order ID  \
# ...

# %%
# where region ='asia' or region='europe' and total revenue > 10000 and total cost between 20k and 40k

df3 = df.loc[(df['Region'].isin(['Asia','Europe'])) & (df['Total Revenue']>10000.0) & (df['Total Cost'].between(20000,40000))]
df3
# Out:
#       Region        Country      Item Type Sales Channel Order Priority  \
# 1     Europe         Latvia      Beverages        Online              C
# 296     Asia      Sri Lanka  Personal Care       Offline              L
# 368   Europe         Kosovo        Clothes       Offline              C
# 379   Europe  Liechtenstein         Fruits        Online              M
# 541   Europe     Montenegro         Fruits       Offline              C
# ...      ...            ...            ...           ...            ...
# 9829  Europe         Kosovo         Fruits        Online              M
# 9844  Europe  Liechtenstein         Fruits       Offline              H
# 9917  Europe          Spain        Clothes        Online              M
# 9926    Asia      Sri Lanka        Clothes        Online              C
# 9999    Asia       Mongolia         Snacks       Offline              M
#
#      Order Date   Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# ...
