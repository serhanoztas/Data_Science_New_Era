# %%
pip install pandas
# Out:
# ...
#   Using cached numpy-2.4.1-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.7 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 31.8 MB/s  0:00:00
# Using cached numpy-2.4.1-cp313-cp313-win_amd64.whl (12.3 MB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

filepath = r'C:\Users\serha\OneDrive\Desktop\Data_Science_New_Era\Data_Science_New_Era\dataset.csv'

# df - dataframe
df = pd.read_csv(filepath)
df = pd.read_csv(filepath, parse_dates=['Order Date', 'Ship Date'])
df.head()
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          10000 non-null  str
#  1   Country         10000 non-null  str
#  2   Item Type       10000 non-null  str
#  3   Sales Channel   10000 non-null  str
#  4   Order Priority  10000 non-null  str
#  5   Order Date      10000 non-null  datetime64[us]
#  6   Order ID        10000 non-null  int64
#  7   Ship Date       10000 non-null  datetime64[us]
#  8   Units Sold      10000 non-null  int64
#  9   Unit Price      10000 non-null  float64
#  10  Unit Cost       10000 non-null  float64
#  11  Total Revenue   10000 non-null  float64
#  12  Total Cost      10000 non-null  float64
#  13  Total Profit    10000 non-null  float64
# dtypes: datetime64[us](2), float64(5), int64(2), str(5)
# memory usage: 1.1 MB
# None

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          10000 non-null  str
#  1   Country         10000 non-null  str
#  2   Item Type       10000 non-null  str
#  3   Sales Channel   10000 non-null  str
#  4   Order Priority  10000 non-null  str
#  5   Order Date      10000 non-null  datetime64[us]
#  6   Order ID        10000 non-null  int64
#  7   Ship Date       10000 non-null  datetime64[us]
#  8   Units Sold      10000 non-null  int64
#  9   Unit Price      10000 non-null  float64
#  10  Unit Cost       10000 non-null  float64
#  11  Total Revenue   10000 non-null  float64
#  12  Total Cost      10000 non-null  float64
#  13  Total Profit    10000 non-null  float64
# dtypes: datetime64[us](2), float64(5), int64(2), str(5)
# memory usage: 1.1 MB
# None

# %%
df['Order Priority'].head()
# Out:
# 0    L
# 1    C
# 2    C
# 3    C
# 4    C
# Name: Order Priority, dtype: str

# %%
df
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority Order Date   Order ID  \
# ...

# %%
df.loc[df['Ship Date']>'2012-12-31'] # Where Clause in SQL
# Out:
#                                  Region                           Country  \
# 1                                Europe                            Latvia
# 4                                Europe                    Czech Republic
# 7                                  Asia                             China
# 8                    Sub-Saharan Africa                           Eritrea
# 9     Central America and the Caribbean                             Haiti
# ...                                 ...                               ...
# 9992              Australia and Oceania                        East Timor
# 9995                               Asia                              Laos
# 9997                 Sub-Saharan Africa  Democratic Republic of the Congo
# 9998                 Sub-Saharan Africa                      South Africa
# 9999                               Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority Order Date   Order ID  \
# ...

# %%
df.loc[df['Region'] == 'Europe', ['Region', 'Country', 'Total Revenue']] 
# select 'Region', 'Country', 'Total Revenue' from dataet where region = 'eruoper'
# select * from dataset where region =
df2 = df.loc[(df['Region'] == 'Europe') & (df['Country'] == 'Latvia')]
print(df2.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 46 entries, 1 to 9405
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          46 non-null     str
#  1   Country         46 non-null     str
#  2   Item Type       46 non-null     str
#  3   Sales Channel   46 non-null     str
#  4   Order Priority  46 non-null     str
#  5   Order Date      46 non-null     datetime64[us]
#  6   Order ID        46 non-null     int64
#  7   Ship Date       46 non-null     datetime64[us]
#  8   Units Sold      46 non-null     int64
#  9   Unit Price      46 non-null     float64
#  10  Unit Cost       46 non-null     float64
#  11  Total Revenue   46 non-null     float64
#  12  Total Cost      46 non-null     float64
#  13  Total Profit    46 non-null     float64
# dtypes: datetime64[us](2), float64(5), int64(2), str(5)
# memory usage: 5.4 KB
# None

# %%
# df[df['Sales Channel'] == 'Offline'].info()
df['Order Priority']

# select region, country where sales channel = offline and order priority in ('H', 'C')
print(type(df['Order Priority']))
print(dir(df['Order Priority']))

df.loc[(df['Sales Channel'] =='Offline') & (df['Order Priority'].isin(['H', 'C'])), ['Region','Country','Order Priority']]
# Out:
# <class 'pandas.Series'>
# ...

# %%
df.loc[(df['Sales Channel'] =='Offline') & (df['Order Priority'].isin(['H', 'C']))]
# Out:
#                             Region           Country      Item Type  \
# 2     Middle East and North Africa          Pakistan     Vegetables
# 5               Sub-Saharan Africa      South Africa      Beverages
# 14    Middle East and North Africa           Algeria        Clothes
# 18    Middle East and North Africa           Lebanon  Personal Care
# 19                          Europe         Lithuania         Snacks
# ...                            ...               ...            ...
# 9977                 North America            Canada      Cosmetics
# 9986                        Europe            Greece     Vegetables
# 9990                          Asia              Laos      Beverages
# 9991                        Europe          Moldova          Snacks
# 9993         Australia and Oceania  Marshall Islands      Baby Food
#
#      Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# 2          Offline              C 2011-01-13  141515767 2011-02-01
# ...

# %%
# select * from dataset where Order Date between 2012-01-01 and 2017-01-01
df.loc[(df['Order Date'] >= '2012-01-01') & (df['Order Date'] <= '2017-01-01')]
df.loc[(df['Order Date'] >= '2012-01-01') & (df['Order Date'] <= '2017-01-01'),['Region','Order ID']]
# Out:
#                      Region                           Country   Item Type  \
# 1                    Europe                            Latvia   Beverages
# 3        Sub-Saharan Africa  Democratic Republic of the Congo   Household
# 4                    Europe                    Czech Republic   Beverages
# 5        Sub-Saharan Africa                      South Africa   Beverages
# 8        Sub-Saharan Africa                           Eritrea        Meat
# ...                     ...                               ...         ...
# 9992  Australia and Oceania                        East Timor   Household
# 9995                   Asia                              Laos   Beverages
# 9996                 Europe                     Liechtenstein   Cosmetics
# 9997     Sub-Saharan Africa  Democratic Republic of the Congo  Vegetables
# 9999                   Asia                          Mongolia      Snacks
#
#      Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# ...

# %%
# select region, country, units sold from ds where region ='asia' and units sold > 10000 ordery by units sold desc limit 5

df.loc[(df['Region'] == 'Asia') & (df['Units Sold'] > 1000), ['Region','Country','Units Sold']].sort_values('Units Sold', ascending=False).head()
# Out:
#      Region     Country  Units Sold
# 128    Asia   Sri Lanka        9997
# 3124   Asia        Laos        9997
# 5569   Asia      Brunei        9996
# 5360   Asia       China        9983
# 9073   Asia  Tajikistan        9983

# %% [markdown]
# select region, sum(total profit) as profit from ds groupy by region;
#
# Latvia 455445454
# Germany 7988787

# %%
# df['Total Profit Groupped'] = 
df[['Region','Total Profit']].groupby('Region').agg({'Total Profit':'sum'})

df.groupby(['Region','Country']).agg(
    Total_Profit_Groupped=('Total Profit', 'sum')
).sort_values(['Region','Country'], ascending=True)


# SELECT REGION,Country, DATEPART(YEAR,[Order Date]) AS ORDERYEAR, SUM([Total Profit])  FROM ds group by REGION,Country, DATEPART(YEAR,[Order Date]
# Out:
#                                Total_Profit_Groupped
# Region             Country
# Asia               Bangladesh            28092720.77
#                    Bhutan                23833769.24
#                    Brunei                21198560.20
#                    Cambodia              23744162.89
#                    China                 24708015.72
# ...                                              ...
# Sub-Saharan Africa The Gambia            18318875.15
#                    Togo                  20026536.18
#                    Uganda                25940655.31
#                    Zambia                23637453.00
#                    Zimbabwe              21174631.76
#
# [185 rows x 1 columns]

# %%
df['Order Date'].dt.year
# Out:
# 0       2011
# 1       2015
# 2       2011
# 3       2012
# 4       2015
#         ...
# 9995    2014
# 9996    2012
# 9997    2013
# 9998    2017
# 9999    2016
# Name: Order Date, Length: 10000, dtype: int32

# %%
df['Order Year'] = df['Order Date'].dt.year

df.groupby(['Region', 'Country', 'Order Year']).agg(
    Total_Profit_Groupped=('Total Profit', 'sum')
).sort_values(['Region','Country','Order Year'], ascending=True)
# Out:
#                                           Total_Profit_Groupped
# Region             Country    Order Year
# Asia               Bangladesh 2010                   4099262.64
#                               2011                   6158192.78
#                               2012                   5019345.59
#                               2013                   4748324.02
#                               2014                   1187588.04
# ...                                                         ...
# Sub-Saharan Africa Zimbabwe   2013                   4361255.37
#                               2014                    424669.93
#                               2015                   3062178.57
#                               2016                   2520913.99
#                               2017                   2527792.01
#
# [1479 rows x 1 columns]
